# %%
import pandas as pd
import numpy as np

# %%
colors = []
colors_and_check = ['Black','Dark Blue','Navy Blue','Royal Blue',
          'Light Blue','Sky Blue','Ash','Dark Ash',
          'Grey','Dark Grey','Coffee Brown','Carton',
          'Green','Wine / Maroon','Red', 
          'Navy Blue and Yellow', 'Ash and Yellow',
          'Dark Ash and Yellow','Light Blue and Yellow',
          'Sky Blue','Light Brown','Dark Brown','Light Green',
          'Dark Green',
         ]
main_colors = ['Black','Dark Blue','Navy Blue','Royal Blue',
          'Light Blue','Sky Blue','Ash','Dark Ash',
          'Grey','Dark Grey','Coffee Brown','Carton',
            'Wine / Maroon','Red',
            'Sky Blue'
         'Light Brown','Dark Brown','Light Green',
          'Dark Green',
         ]

sizes = [36,38,40,42,44,46,48,50,52,54,56,58,60,62,64,66,68,70]

types = ['Plain','Rough Surface','Tiny Stripe','Big stripe','Check',
         'Dotted',
         # 'Codro'
        ]

sex = ['male','Female']
buttons = ['Single Button','Double Button']
breasteds = ['None',"Double Breasted"]
golden_button = ['No']

pics = [
        # '1pc (top)',
        '2pcs (top, Trouser)','3pcs (top, Trouser, Jacket)'
       ]

sleeves = ['long']

product = 'Suit'
category = {'Normal Suit':['Dinoman','Dino Casila','Casila','Kenneth Samantha',
                           'Die Caprie','Magnate','Cash Time','Daro','Orange'
                          
                          ],
            '1st Turkish Suit':['Eletto','Zecca','Finesse','Frank Sivero',
                               'Mario Santana','Nevio',"Luis Armoni",
                                'Alberto Biagio','Torpedo','Utes',
                                'Legolas','Zeymond Zerga','Ziganali',
                                'Piserro','Konzi','Charles Brown',
                                'Matteo Valders'
                               ],
            '2nd Turkish Suit':['Faith Zerek','Faith','Luis Armoni',
                               'Pilucci','Mario Casas','Ramzotti',
                               'Maestro','Belfor','senzo','Bronzi',
                               'Garlando'],
            # 'Normal Blazer': ['Safari','Bishop Neck'],
            'Normal Blazer': ['Roy Robson','Next','Casila','Kenneth Samatha','D. Shanba','Blaclman',
                             'Jaboer','Arare Lacroix','Die Caprie'],
            '1st Turkish Blazer': ['Man Diamond','Marco Milano','Federico Grunti',
                                   'Orange','Boladino','Alberto Biago',"Mario Santana",
                                   'Roy Robson','Piro Brano','Antonizanetti','Fabio Rossi',
                                   "Marco Milano", "Federico Guinti",'Maverick Creation'
                                  ],
            '2nd Turkish Blazer': ['Man Diamond','Marco Milano','Federico Grunti',
                                   'Orange','Boladino','Alberto Biago',"Mario Santana",
                                   'Roy Robson',"Maligan",'Kenneth KC Cole'
                                  ],
            # "Tuxedo": ['Senzo','Maestro','Utes','Decaprie',"Maligan"]
           }

# %%
cols = ['Product','Category','Brand','Type','Sex','Color','Size',
        'sleeves','Breasted','Button','Pics', 'Golden Button',
       ]
len(cols)
# Out:
# 12

# %%
# special cases

# tuxedo flower
# safari suit
# Bishop neck
# check done

# 3057600 rows

# %%
data = []
for gender in sex:
    temp = []
    for cat,brands in category.items():
        
        if gender == "Female" and cat not in ['Normal Suit',
                                               '1st Turkish Suit',
                                               '2nd Turkish Suit']:
                continue
        if cat not in ['Normal Suit',
                        '1st Turkish Suit',
                        '2nd Turkish Suit',
                        "Tuxedo",
                                ]:
            
                pics = [ '1pc (top)']
        else:
                pics = [
                    # '1pc (top)',
         '2pcs (top, Trouser)','3pcs (top, Trouser, Inner Jacket)'
           ]
        for brand in brands:
            if cat in [
                        '1st Turkish Suit',
                        '2nd Turkish Suit'] and brand in  ['Maestro','Senzo']:
                golden_button = ['Yes','No']
            else:
                golden_button = ['No']
                
            # if brand not in ['Zeymond Zerga','Ziganali','Piserro','Mario Casas','Senzo']:
            #     breasteds = ['None']
            # else:
            #     breasteds = ['None',"Double Breasted"]
                
            for sleeve in sleeves:

                for breasted in breasteds:
                    for pic in pics:
                        for golden in golden_button:

                            # for cat,brands in category.items():
                            for button in buttons:
                                # for brand in brands:
                                    for type_ in types:
                                        if type_ == "Check":
                                            colors = colors_and_check
                                        else:
                                            colors = main_colors

                                        for color in colors:
                                            for size in sizes:
                                                temp = [product,cat,brand,type_,gender,
                                                        color,size,sleeve,
                                                        breasted,button,pic,golden]
                                                data.append(temp)
                                        
len(temp)
# Out:
# 12

# %%
df = pd.DataFrame(data,columns=cols)

# %%
df.shape
# Out:
# (1518480, 12)

# %%
data = df[(df['Category'] == '1st Turkish Suit') & (df['Pics'] == "3pcs (top, Trouser, Inner Jacket)")]
df.drop(data.index,axis=0,inplace=True)

data = df[(df['Category'] == '2st Turkish Suit') & (df['Pics'] == "2pcs (top, Trouser)")]
df.drop(data.index,axis=0,inplace=True)

# %%
data = df[(df['Breasted'] == 'Double Breasted') & (df['Button'] == "Single Button")]
df.drop(data.index,axis=0,inplace=True)

# %%
df.shape
# Out:
# (929556, 12)

# %%
df[df.Breasted == 'Double Breasted'].Category.unique()
# Out:
# array(['Normal Suit', '1st Turkish Suit', '2nd Turkish Suit',
#        'Normal Blazer', '1st Turkish Blazer', '2nd Turkish Blazer'],
#       dtype=object)

# %%
df[df.Breasted == 'Double Breasted']
# Out:
#         Product          Category     Brand    Type     Sex       Color  Size  \
# 10260      Suit       Normal Suit   Dinoman   Plain    male       Black    36
# 10261      Suit       Normal Suit   Dinoman   Plain    male       Black    38
# 10262      Suit       Normal Suit   Dinoman   Plain    male       Black    40
# 10263      Suit       Normal Suit   Dinoman   Plain    male       Black    42
# 10264      Suit       Normal Suit   Dinoman   Plain    male       Black    44
# ...         ...               ...       ...     ...     ...         ...   ...
# 1518475    Suit  2nd Turkish Suit  Garlando  Dotted  Female  Dark Green    62
# 1518476    Suit  2nd Turkish Suit  Garlando  Dotted  Female  Dark Green    64
# 1518477    Suit  2nd Turkish Suit  Garlando  Dotted  Female  Dark Green    66
# 1518478    Suit  2nd Turkish Suit  Garlando  Dotted  Female  Dark Green    68
# 1518479    Suit  2nd Turkish Suit  Garlando  Dotted  Female  Dark Green    70
#
# ...

# %%
df.Category.unique()
# Out:
# array(['Normal Suit', '1st Turkish Suit', '2nd Turkish Suit',
#        'Normal Blazer', '1st Turkish Blazer', '2nd Turkish Blazer'],
#       dtype=object)

# %%
normal = df[df.Category == 'Normal Suit']

# %%
normal
# Out:
#         Product     Category    Brand    Type     Sex       Color  Size  \
# 0          Suit  Normal Suit  Dinoman   Plain    male       Black    36
# 1          Suit  Normal Suit  Dinoman   Plain    male       Black    38
# 2          Suit  Normal Suit  Dinoman   Plain    male       Black    40
# 3          Suit  Normal Suit  Dinoman   Plain    male       Black    42
# 4          Suit  Normal Suit  Dinoman   Plain    male       Black    44
# ...         ...          ...      ...     ...     ...         ...   ...
# 1042411    Suit  Normal Suit   Orange  Dotted  Female  Dark Green    62
# 1042412    Suit  Normal Suit   Orange  Dotted  Female  Dark Green    64
# 1042413    Suit  Normal Suit   Orange  Dotted  Female  Dark Green    66
# 1042414    Suit  Normal Suit   Orange  Dotted  Female  Dark Green    68
# 1042415    Suit  Normal Suit   Orange  Dotted  Female  Dark Green    70
#
#         sleeves         Breasted         Button  \
# 0          long             None  Single Button
# ...

# %%
df.query('Sex == "male"',inplace=True)

# %%
first_turkish_suit = df[df.Category == '1st Turkish Suit']

# %%
first_turkish_suit
# Out:
#        Product          Category           Brand    Type   Sex       Color  \
# 147744    Suit  1st Turkish Suit          Eletto   Plain  male       Black
# 147745    Suit  1st Turkish Suit          Eletto   Plain  male       Black
# 147746    Suit  1st Turkish Suit          Eletto   Plain  male       Black
# 147747    Suit  1st Turkish Suit          Eletto   Plain  male       Black
# 147748    Suit  1st Turkish Suit          Eletto   Plain  male       Black
# ...        ...               ...             ...     ...   ...         ...
# 422707    Suit  1st Turkish Suit  Matteo Valders  Dotted  male  Dark Green
# 422708    Suit  1st Turkish Suit  Matteo Valders  Dotted  male  Dark Green
# 422709    Suit  1st Turkish Suit  Matteo Valders  Dotted  male  Dark Green
# 422710    Suit  1st Turkish Suit  Matteo Valders  Dotted  male  Dark Green
# 422711    Suit  1st Turkish Suit  Matteo Valders  Dotted  male  Dark Green
#
# ...

# %%
first_turkish_suit.Brand.unique()
# Out:
# array(['Eletto', 'Zecca', 'Finesse', 'Frank Sivero', 'Mario Santana',
#        'Nevio', 'Luis Armoni', 'Alberto Biagio', 'Torpedo', 'Utes',
#        'Legolas', 'Zeymond Zerga', 'Ziganali', 'Piserro', 'Konzi',
#        'Charles Brown', 'Matteo Valders'], dtype=object)

# %%
f_eletto = first_turkish_suit[first_turkish_suit.Brand=="Eletto"]

# %%
f_eletto.Type.unique()
# Out:
# array(['Plain', 'Rough Surface', 'Tiny Stripe', 'Big stripe', 'Check',
#        'Dotted'], dtype=object)

# %%
f_eletto.Color.unique()
# Out:
# array(['Black', 'Dark Blue', 'Navy Blue', 'Royal Blue', 'Light Blue',
#        'Sky Blue', 'Ash', 'Dark Ash', 'Grey', 'Dark Grey', 'Coffee Brown',
#        'Carton', 'Wine / Maroon', 'Red', 'Sky BlueLight Brown',
#        'Dark Brown', 'Light Green', 'Dark Green', 'Green',
#        'Navy Blue and Yellow', 'Ash and Yellow', 'Dark Ash and Yellow',
#        'Light Blue and Yellow', 'Light Brown'], dtype=object)

# %%
f_eletto.Size.unique()
# Out:
# array([36, 38, 40, 42, 44, 46, 48, 50, 52, 54, 56, 58, 60, 62, 64, 66, 68,
#        70], dtype=int64)

# %%
s_data = df[(df['Category'] == '1st Turkish Suit') & (df['Brand'] == 'Eletto') ]
s_data.to_excel('eletto_1st_turkish_suit.xlsx')

# %%
# f_eletto.Color.unique()

f_eletto.sleeves.unique()
# Out:
# array(['long'], dtype=object)

# %%
f_eletto.Breasted.unique()
# Out:
# array(['None', 'Double Breasted'], dtype=object)

# %%
f_eletto.Button.unique()
# Out:
# array(['Single Button', 'Double Button'], dtype=object)

# %%
f_eletto.Pics.unique()
# Out:
# array(['2pcs (top, Trouser)'], dtype=object)

# %%
# df[df.Category == 'Normal Suit']
# f_eletto.query('Pics == "2pcs (top, Trouser)" ',inplace=True)

# %%
f_eletto
# Out:
#        Product          Category   Brand    Type   Sex       Color  Size  \
# 147744    Suit  1st Turkish Suit  Eletto   Plain  male       Black    36
# 147745    Suit  1st Turkish Suit  Eletto   Plain  male       Black    38
# 147746    Suit  1st Turkish Suit  Eletto   Plain  male       Black    40
# 147747    Suit  1st Turkish Suit  Eletto   Plain  male       Black    42
# 147748    Suit  1st Turkish Suit  Eletto   Plain  male       Black    44
# ...        ...               ...     ...     ...   ...         ...   ...
# 160051    Suit  1st Turkish Suit  Eletto  Dotted  male  Dark Green    62
# 160052    Suit  1st Turkish Suit  Eletto  Dotted  male  Dark Green    64
# 160053    Suit  1st Turkish Suit  Eletto  Dotted  male  Dark Green    66
# 160054    Suit  1st Turkish Suit  Eletto  Dotted  male  Dark Green    68
# 160055    Suit  1st Turkish Suit  Eletto  Dotted  male  Dark Green    70
#
#        sleeves         Breasted         Button                 Pics  \
# ...

# %%
f_eletto['Golden Button'].unique()
# Out:
# array(['No'], dtype=object)

# %%
df[df['Golden Button'] == 'Yes']
# Out:
#        Product          Category    Brand    Type   Sex       Color  Size  \
# 525312    Suit  2nd Turkish Suit  Maestro   Plain  male       Black    36
# 525313    Suit  2nd Turkish Suit  Maestro   Plain  male       Black    38
# 525314    Suit  2nd Turkish Suit  Maestro   Plain  male       Black    40
# 525315    Suit  2nd Turkish Suit  Maestro   Plain  male       Black    42
# 525316    Suit  2nd Turkish Suit  Maestro   Plain  male       Black    44
# ...        ...               ...      ...     ...   ...         ...   ...
# 554035    Suit  2nd Turkish Suit  Maestro  Dotted  male  Dark Green    62
# 554036    Suit  2nd Turkish Suit  Maestro  Dotted  male  Dark Green    64
# 554037    Suit  2nd Turkish Suit  Maestro  Dotted  male  Dark Green    66
# 554038    Suit  2nd Turkish Suit  Maestro  Dotted  male  Dark Green    68
# 554039    Suit  2nd Turkish Suit  Maestro  Dotted  male  Dark Green    70
#
#        sleeves         Breasted         Button  \
# ...

# %%
df[df.Category == 'Normal Suit'].Type.unique()
# Out:
# array(['Plain', 'Rough Surface', 'Tiny Stripe', 'Big stripe', 'Check',
#        'Dotted'], dtype=object)

# %%
# Normal_suits = df[df.Category == 'Normal Suit']

# %%
# Normal_suits.to_excel('normal_suits.xlsx',index=False)

# %%
# colors = []
colors= ['Black','Dark Blue','Navy Blue','Royal Blue',
          'Light Blue','Sky Blue','Ash','Dark Ash',
          'Grey','Dark Grey','Coffee Brown','Carton',
          'Green','Wine / Maroon','Red', 
          'Navy Blue and Yellow', 'Ash and Yellow',
          'Dark Ash and Yellow','Light Blue and Yellow',
          'Sky Blue','Light Brown','Dark Brown','Light Green',
          'Dark Green',
        ]

sizes = [36,38,40,42,44,46,48,50,52,54,56,58,60,62,64,66,68,70]

types = ['Plain','Design',
         # 'Codro'
        ]

sex = ['male']
buttons = ['multi']
breasteds = ['None']
golden_button = ['No']

pics = [
        # '1pc (top)',
        '2pcs (top, Trouser)'
       ]

sleeves = ['long','short']

product = 'Bishop Neck Suit'
category = {'Normal':['Arare','Die Caprie','Daro','AN & Cole'
                          ],
          
           }

cols = ['Product','Category','Brand','Type','Sex','Color','Size',
        'sleeves','Breasted','Button','Pics', 'Golden Button',
       ]

# %%
data = []
for gender in sex:
    temp = []
    for cat,brands in category.items():
        for brand in brands:
            for sleeve in sleeves:

                for breasted in breasteds:
                    for pic in pics:
                        for golden in golden_button:

                            # for cat,brands in category.items():
                            for button in buttons:
                                # for brand in brands:
                                    for type_ in types:
                                        for color in colors:
                                            for size in sizes:
                                                temp = [product,cat,brand,type_,gender,
                                                        color,size,sleeve,
                                                        breasted,button,pic,golden]
                                                data.append(temp)
                                        
len(temp)
# Out:
# 12

# %%
bushop_neck = pd.DataFrame(data,columns=cols)

# %%
bushop_neck
# Out:
#                Product Category      Brand    Type   Sex       Color  Size  \
# 0     Bishop Neck Suit   Normal      Arare   Plain  male       Black    36
# 1     Bishop Neck Suit   Normal      Arare   Plain  male       Black    38
# 2     Bishop Neck Suit   Normal      Arare   Plain  male       Black    40
# 3     Bishop Neck Suit   Normal      Arare   Plain  male       Black    42
# 4     Bishop Neck Suit   Normal      Arare   Plain  male       Black    44
# ...                ...      ...        ...     ...   ...         ...   ...
# 6907  Bishop Neck Suit   Normal  AN & Cole  Design  male  Dark Green    62
# 6908  Bishop Neck Suit   Normal  AN & Cole  Design  male  Dark Green    64
# 6909  Bishop Neck Suit   Normal  AN & Cole  Design  male  Dark Green    66
# 6910  Bishop Neck Suit   Normal  AN & Cole  Design  male  Dark Green    68
# 6911  Bishop Neck Suit   Normal  AN & Cole  Design  male  Dark Green    70
#
#      sleeves Breasted Button                 Pics Golden Button
# ...

# %%
# colors = []
colors= ['Black','Dark Blue','Navy Blue','Royal Blue',
          'Light Blue','Sky Blue','Ash','Dark Ash',
          'Grey','Dark Grey','Coffee Brown','Carton',
          'Green','Wine / Maroon','Red', 
          'Navy Blue and Yellow', 'Ash and Yellow',
          'Dark Ash and Yellow','Light Blue and Yellow',
          'Sky Blue','Light Brown','Dark Brown','Light Green',
          'Dark Green',
        ]

sizes = [36,38,40,42,44,46,48,50,52,54,56,58,60,62,64,66,68,70]

types = ['Plain','Design',
         # 'Codro'
        ]

sex = ['male']
buttons = ['multi']
breasteds = ['None']
golden_button = ['No']

pics = [
        # '1pc (top)',
        '2pcs (top, Trouser)'
       ]

sleeves = ['short']

product = 'Safari Suit'
category = {'Normal':['Arare','Die Caprie','Daro','AN & Cole'
                          ],
          
           }

cols = ['Product','Category','Brand','Type','Sex','Color','Size',
        'sleeves','Breasted','Button','Pics', 'Golden Button',
       ]

# %%
data = []
for gender in sex:
    temp = []
    for cat,brands in category.items():
        for brand in brands:
            for sleeve in sleeves:

                for breasted in breasteds:
                    for pic in pics:
                        for golden in golden_button:

                            # for cat,brands in category.items():
                            for button in buttons:
                                # for brand in brands:
                                    for type_ in types:
                                        for color in colors:
                                            for size in sizes:
                                                temp = [product,cat,brand,type_,gender,
                                                        color,size,sleeve,
                                                        breasted,button,pic,golden]
                                                data.append(temp)
                                        
len(temp)
# Out:
# 12

# %%
safari_suit = pd.DataFrame(data,columns=cols)

# %%
safari_suit
# Out:
#           Product Category      Brand    Type   Sex       Color  Size sleeves  \
# 0     Safari Suit   Normal      Arare   Plain  male       Black    36   short
# 1     Safari Suit   Normal      Arare   Plain  male       Black    38   short
# 2     Safari Suit   Normal      Arare   Plain  male       Black    40   short
# 3     Safari Suit   Normal      Arare   Plain  male       Black    42   short
# 4     Safari Suit   Normal      Arare   Plain  male       Black    44   short
# ...           ...      ...        ...     ...   ...         ...   ...     ...
# 3451  Safari Suit   Normal  AN & Cole  Design  male  Dark Green    62   short
# 3452  Safari Suit   Normal  AN & Cole  Design  male  Dark Green    64   short
# 3453  Safari Suit   Normal  AN & Cole  Design  male  Dark Green    66   short
# 3454  Safari Suit   Normal  AN & Cole  Design  male  Dark Green    68   short
# 3455  Safari Suit   Normal  AN & Cole  Design  male  Dark Green    70   short
#
# ...

# %%
# colors = []
colors= ['Black','Light Brown','Coffee Brown','grey',
          'Dark Green',
        ]

sizes = [36,38,40,42,44,46,48,50,52,54,56,58,60,62,64,66,68,70]

types = ['Plain','Design',
         # 'Codro'
        ]

sex = ['male']
buttons = ['multi']
breasteds = ['None']
golden_button = ['No']

pics = [
        # '1pc (top)',
        '2pcs (top, Trouser)'
       ]

sleeves = ['short']

product = 'Chinos Suit'
category = {'Normal':['Kenneth KC Cole'
                          ],
          
           }

cols = ['Product','Category','Brand','Type','Sex','Color','Size',
        'sleeves','Breasted','Button','Pics', 'Golden Button',
       ]

# %%
data = []
for gender in sex:
    temp = []
    for cat,brands in category.items():
        for brand in brands:
            for sleeve in sleeves:

                for breasted in breasteds:
                    for pic in pics:
                        for golden in golden_button:

                            # for cat,brands in category.items():
                            for button in buttons:
                                # for brand in brands:
                                    for type_ in types:
                                        for color in colors:
                                            for size in sizes:
                                                temp = [product,cat,brand,type_,gender,
                                                        color,size,sleeve,
                                                        breasted,button,pic,golden]
                                                data.append(temp)
                                        
len(temp)
# Out:
# 12

# %%
chinos_suit = pd.DataFrame(data,columns=cols)

# %%
chinos_suit
# Out:
#          Product Category            Brand    Type   Sex       Color  Size  \
# 0    Chinos Suit   Normal  Kenneth KC Cole   Plain  male       Black    36
# 1    Chinos Suit   Normal  Kenneth KC Cole   Plain  male       Black    38
# 2    Chinos Suit   Normal  Kenneth KC Cole   Plain  male       Black    40
# 3    Chinos Suit   Normal  Kenneth KC Cole   Plain  male       Black    42
# 4    Chinos Suit   Normal  Kenneth KC Cole   Plain  male       Black    44
# ..           ...      ...              ...     ...   ...         ...   ...
# 175  Chinos Suit   Normal  Kenneth KC Cole  Design  male  Dark Green    62
# 176  Chinos Suit   Normal  Kenneth KC Cole  Design  male  Dark Green    64
# 177  Chinos Suit   Normal  Kenneth KC Cole  Design  male  Dark Green    66
# 178  Chinos Suit   Normal  Kenneth KC Cole  Design  male  Dark Green    68
# 179  Chinos Suit   Normal  Kenneth KC Cole  Design  male  Dark Green    70
#
#     sleeves Breasted Button                 Pics Golden Button
# ...

# %%
# colors = []
colors = ['Black','Dark Blue','Navy Blue','Royal Blue',
          'Light Blue','Sky Blue','Ash','Dark Ash',
          'Grey','Dark Grey','Coffee Brown','Carton',
          'Green','Wine / Maroon','Red', 
          'Navy Blue and Yellow', 'Ash and Yellow',
          'Dark Ash and Yellow','Light Blue and Yellow',
          'Sky Blue','Light Brown','Dark Brown','Light Green',
          'Dark Green',
         ]

sizes = [36,38,40,42,44,46,48,50,52,54,56,58,60,62,64,66,68,70]

types = ['Plain','Design',
         # 'Codro'
        ]

sex = ['male']
buttons = ['single']
breasteds = ['None']
golden_button = ['No']

pics = [
        # '1pc (top)',
        '3pcs (top, Trouser, Inner Jacket)'
       ]

sleeves = ['Long']

product = 'Tuxedo Suit'
category = {'Normal':['Die Caprice','Maligan'],
            '2nd Turkish Shirt':['Maestro','Senzo'],
           }

cols = ['Product','Category','Brand','Type','Sex','Color','Size',
        'sleeves','Breasted','Button','Pics', 'Golden Button',
       ]

# %%
data = []
for gender in sex:
    temp = []
    for cat,brands in category.items():
        for brand in brands:
            for sleeve in sleeves:

                for breasted in breasteds:
                    for pic in pics:
                        for golden in golden_button:

                            # for cat,brands in category.items():
                            for button in buttons:
                                # for brand in brands:
                                    for type_ in types:
                                        for color in colors:
                                            for size in sizes:
                                                temp = [product,cat,brand,type_,gender,
                                                        color,size,sleeve,
                                                        breasted,button,pic,golden]
                                                data.append(temp)
                                        
len(temp)
# Out:
# 12

# %%
tuxedo_adult_suit = pd.DataFrame(data,columns=cols)
tuxedo_adult_suit
# Out:
#           Product           Category        Brand    Type   Sex       Color  \
# 0     Tuxedo Suit             Normal  Die Caprice   Plain  male       Black
# 1     Tuxedo Suit             Normal  Die Caprice   Plain  male       Black
# 2     Tuxedo Suit             Normal  Die Caprice   Plain  male       Black
# 3     Tuxedo Suit             Normal  Die Caprice   Plain  male       Black
# 4     Tuxedo Suit             Normal  Die Caprice   Plain  male       Black
# ...           ...                ...          ...     ...   ...         ...
# 3451  Tuxedo Suit  2nd Turkish Shirt        Senzo  Design  male  Dark Green
# 3452  Tuxedo Suit  2nd Turkish Shirt        Senzo  Design  male  Dark Green
# 3453  Tuxedo Suit  2nd Turkish Shirt        Senzo  Design  male  Dark Green
# 3454  Tuxedo Suit  2nd Turkish Shirt        Senzo  Design  male  Dark Green
# 3455  Tuxedo Suit  2nd Turkish Shirt        Senzo  Design  male  Dark Green
#
# ...

# %%
# colors = []
colors = ['Black','Dark Blue','Navy Blue','Royal Blue',
          'Light Blue','Sky Blue','Ash','Dark Ash',
          'Grey','Dark Grey','Coffee Brown','Carton',
          'Green','Wine / Maroon','Red', 
          'Navy Blue and Yellow', 'Ash and Yellow',
          'Dark Ash and Yellow','Light Blue and Yellow',
          'Sky Blue','Light Brown','Dark Brown','Light Green',
          'Dark Green',
         ]

sizes = [20,22,24,26,28,30,32,34,36,38,
         40,42,44,46,48,50,52,54,56,58,
         60,62,64,66,68,70,72,74,76]

types = ['Plain','Design',
         # 'Codro'
        ]

sex = ['male']
buttons = ['single']
breasteds = ['None']
golden_button = ['No']

pics = [
        # '1pc (top)',
        '2pcs (top, Trouser)',
        '3pcs (top, Trouser, Inner Jacket)',
       ]

sleeves = ['Long']

product = 'Tuxedo Suit'
category = {'Normal':['Ping Pp Pu','Kaerbindu','T.M Lewis',
                     'Gold key','De Candis'
                     ],
           }

cols = ['Product','Category','Brand','Type','Sex','Color','Size',
        'sleeves','Breasted','Button','Pics', 'Golden Button',
       ]

# %%
data = []
for gender in sex:
    temp = []
    for cat,brands in category.items():
        for brand in brands:
            for sleeve in sleeves:

                for breasted in breasteds:
                    for pic in pics:
                        for golden in golden_button:

                            # for cat,brands in category.items():
                            for button in buttons:
                                # for brand in brands:
                                    for type_ in types:
                                        for color in colors:
                                            for size in sizes:
                                                temp = [product,cat,brand,type_,gender,
                                                        color,size,sleeve,
                                                        breasted,button,pic,golden]
                                                data.append(temp)
                                        
len(temp)
# Out:
# 12

# %%
tuxedo_children_suit = pd.DataFrame(data,columns=cols)
tuxedo_children_suit
# Out:
#            Product Category       Brand    Type   Sex       Color  Size  \
# 0      Tuxedo Suit   Normal  Ping Pp Pu   Plain  male       Black    20
# 1      Tuxedo Suit   Normal  Ping Pp Pu   Plain  male       Black    22
# 2      Tuxedo Suit   Normal  Ping Pp Pu   Plain  male       Black    24
# 3      Tuxedo Suit   Normal  Ping Pp Pu   Plain  male       Black    26
# 4      Tuxedo Suit   Normal  Ping Pp Pu   Plain  male       Black    28
# ...            ...      ...         ...     ...   ...         ...   ...
# 13915  Tuxedo Suit   Normal   De Candis  Design  male  Dark Green    68
# 13916  Tuxedo Suit   Normal   De Candis  Design  male  Dark Green    70
# 13917  Tuxedo Suit   Normal   De Candis  Design  male  Dark Green    72
# 13918  Tuxedo Suit   Normal   De Candis  Design  male  Dark Green    74
# 13919  Tuxedo Suit   Normal   De Candis  Design  male  Dark Green    76
#
#       sleeves Breasted  Button                               Pics  \
# ...

# %%
# colors = []
colors = ['Black','Dark Blue','Navy Blue','Royal Blue',
          'Light Blue','Sky Blue','Ash','Dark Ash',
          'Grey','Dark Grey','Coffee Brown','Carton',
          'Green','Wine / Maroon','Red', 
          'Navy Blue and Yellow', 'Ash and Yellow',
          'Dark Ash and Yellow','Light Blue and Yellow',
          'Sky Blue','Light Brown','Dark Brown','Light Green',
          'Dark Green',
         ]

sizes = [20,22,24,26,28,30,32,34,36,38,
         40,42,44,46,48,50,52,54,56,58,
         60,62,64,66,68,70,72,74,76]

types = ['Plain',
         # 'Codro'
        ]

sex = ['male']
buttons = ['single']
breasteds = ['None']
golden_button = ['No']

pics = [
        # '1pc (top)',
        '2pcs (top, Trouser)',
        '3pcs (top, Trouser, Inner Jacket)',
       ]

sleeves = ['Long']

product = 'Suit'
category = {'Normal':['Ping Pp Pu','Kaerbindu','T.M Lewis',
                     'Gold key','De Candis'
                     ],
           }

cols = ['Product','Category','Brand','Type','Sex','Color','Size',
        'sleeves','Breasted','Button','Pics', 'Golden Button',
       ]

# %%
data = []
for gender in sex:
    temp = []
    for cat,brands in category.items():
        for brand in brands:
            for sleeve in sleeves:

                for breasted in breasteds:
                    for pic in pics:
                        for golden in golden_button:

                            # for cat,brands in category.items():
                            for button in buttons:
                                # for brand in brands:
                                    for type_ in types:
                                        for color in colors:
                                            for size in sizes:
                                                temp = [product,cat,brand,type_,gender,
                                                        color,size,sleeve,
                                                        breasted,button,pic,golden]
                                                data.append(temp)
                                        
len(temp)
# Out:
# 12

# %%
children_suit = pd.DataFrame(data,columns=cols)
children_suit
# Out:
#      Product Category       Brand   Type   Sex       Color  Size sleeves  \
# 0       Suit   Normal  Ping Pp Pu  Plain  male       Black    20    Long
# 1       Suit   Normal  Ping Pp Pu  Plain  male       Black    22    Long
# 2       Suit   Normal  Ping Pp Pu  Plain  male       Black    24    Long
# 3       Suit   Normal  Ping Pp Pu  Plain  male       Black    26    Long
# 4       Suit   Normal  Ping Pp Pu  Plain  male       Black    28    Long
# ...      ...      ...         ...    ...   ...         ...   ...     ...
# 6955    Suit   Normal   De Candis  Plain  male  Dark Green    68    Long
# 6956    Suit   Normal   De Candis  Plain  male  Dark Green    70    Long
# 6957    Suit   Normal   De Candis  Plain  male  Dark Green    72    Long
# 6958    Suit   Normal   De Candis  Plain  male  Dark Green    74    Long
# 6959    Suit   Normal   De Candis  Plain  male  Dark Green    76    Long
#
#      Breasted  Button                               Pics Golden Button
# ...

# %%
colors = []
colors_and_check = ['Black','Dark Blue','Navy Blue','Royal Blue',
          'Light Blue','Sky Blue','Ash','Dark Ash',
          'Grey','Dark Grey','Coffee Brown','Carton',
          'Green','Wine / Maroon','Red', 
          'Navy Blue and Yellow', 'Ash and Yellow',
          'Dark Ash and Yellow','Light Blue and Yellow',
          'Sky Blue','Light Brown','Dark Brown','Light Green',
          'Dark Green',
         ]
main_colors = ['Black','Dark Blue','Navy Blue','Royal Blue',
          'Light Blue','Sky Blue','Ash','Dark Ash',
          'Grey','Dark Grey','Coffee Brown','Carton',
            'Wine / Maroon','Red',
            'Sky Blue'
         'Light Brown','Dark Brown','Light Green',
          'Dark Green',
         ]

sizes = [34,36,38,40,42,44,46,48,50,52,54,56,58,60]

types = ['Plain','Rough Surface','Tiny Stripe','Big stripe','Check',
         'Dotted',
         # 'Codro'
        ]

sex = ['Female']
buttons = ['Single Button','Double Button']
breasteds = ['None',"Double Breasted"]
golden_button = ['No']

pics = [
        # '1pc (top)',
        '2pcs (top, Trouser)','3pcs (top, Trouser, Jacket)'
       ]

sleeves = ['long']

product = 'Suit'
category = {'Normal Suit':['Aviva','Bonfita','Patos',  
                          ],
            '2nd Turkish Suit':['None'],
            # 'Normal Blazer': ['Safari','Bishop Neck'],
            'Normal Blazer': ['Roy Robson','Next','Casila','Kenneth Samatha','D. Shanba','Blaclman',
                             'Jaboer','Arare Lacroix','Die Caprie'],
            '1st Turkish Blazer': ['None'
                                  ],
            '2nd Turkish Blazer': ['None'
                                  ],
            # "Tuxedo": ['Senzo','Maestro','Utes','Decaprie',"Maligan"]
           }

# %%
cols = ['Product','Category','Brand','Type','Sex','Color','Size',
        'sleeves','Breasted','Button','Pics', 'Golden Button',
       ]
len(cols)
# Out:
# 12

# %%
data = []
for gender in sex:
    temp = []
    for cat,brands in category.items():
        
        if gender == "Female" and cat not in ['Normal Suit',
                                               '1st Turkish Suit',
                                               '2nd Turkish Suit']:
                continue
        if cat not in ['Normal Suit',
                        '1st Turkish Suit',
                        '2nd Turkish Suit',
                        "Tuxedo",
                                ]:
            
                pics = [ '1pc (top)']
        else:
                pics = [
                    # '1pc (top)',
         '2pcs (top, Trouser)'
           ]
        for brand in brands:
            if cat in [
                        '1st Turkish Suit',
                        '2nd Turkish Suit'] and brand in  ['Maestro','Senzo']:
                golden_button = ['Yes','No']
            else:
                golden_button = ['No']
                
            # if brand not in ['Zeymond Zerga','Ziganali','Piserro','Mario Casas','Senzo']:
            #     breasteds = ['None']
            # else:
            #     breasteds = ['None',"Double Breasted"]
                
            for sleeve in sleeves:

                for breasted in breasteds:
                    for pic in pics:
                        for golden in golden_button:

                            # for cat,brands in category.items():
                            for button in buttons:
                                # for brand in brands:
                                    for type_ in types:
                                        if type_ == "Check":
                                            colors = colors_and_check
                                        else:
                                            colors = main_colors

                                        for color in colors:
                                            for size in sizes:
                                                temp = [product,cat,brand,type_,gender,
                                                        color,size,sleeve,
                                                        breasted,button,pic,golden]
                                                data.append(temp)
                                        
len(temp)
# Out:
# 12

# %%
female_suits = pd.DataFrame(data,columns=cols)

# %%
data = female_suits[(female_suits['Category'] == '1st Turkish Suit') & (female_suits['Pics'] == "3pcs (top, Trouser, Inner Jacket)")]
female_suits.drop(data.index,axis=0,inplace=True)

data = female_suits[(female_suits['Category'] == '2st Turkish Suit') & (female_suits['Pics'] == "2pcs (top, Trouser)")]
female_suits.drop(data.index,axis=0,inplace=True)

data = female_suits[(female_suits['Breasted'] == 'Double Breasted') & (female_suits['Button'] == "Single Button")]
female_suits.drop(data.index,axis=0,inplace=True)

# %%
female_suits
# Out:
#       Product          Category  Brand    Type     Sex       Color  Size  \
# 0        Suit       Normal Suit  Aviva   Plain  Female       Black    34
# 1        Suit       Normal Suit  Aviva   Plain  Female       Black    36
# 2        Suit       Normal Suit  Aviva   Plain  Female       Black    38
# 3        Suit       Normal Suit  Aviva   Plain  Female       Black    40
# 4        Suit       Normal Suit  Aviva   Plain  Female       Black    42
# ...       ...               ...    ...     ...     ...         ...   ...
# 25531    Suit  2nd Turkish Suit   None  Dotted  Female  Dark Green    52
# 25532    Suit  2nd Turkish Suit   None  Dotted  Female  Dark Green    54
# 25533    Suit  2nd Turkish Suit   None  Dotted  Female  Dark Green    56
# 25534    Suit  2nd Turkish Suit   None  Dotted  Female  Dark Green    58
# 25535    Suit  2nd Turkish Suit   None  Dotted  Female  Dark Green    60
#
#       sleeves         Breasted         Button                 Pics  \
# ...

# %%
cols = ['Product','Category','Brand','Type',
        'sex','Color','Size','sleeves',
       ]
colors = []
# colors_and_check = ['Black','Dark Blue','Navy Blue','Royal Blue'
#           'Light Blue','Sky Blue','Ash','Dark Ash',
#           'Grey','Dark Grey','Coffee Brown','Carton',
#           'Green','Wine / Maroon','Red', 
#           'Navy Blue and Yellow', 'Ash and Yellow',
#           'Dark Ash and Yellow','Light Blue and Yellow'
#          ]
colors = ['white','Black','Sky Blue',
               'Navy Blue','Light Blue','Ash',
               'Grey','Brown','Green','Light Green',
               'Wine / Maroon','Purple','Pink',
               'Red','Lemon','Light Carton','Milk',
               'Orange','Peach'
               
         ]

# sizes = [36,38,40,42,44,46,48,50,52,54,56,58,60,62,64,66]

sizes_ = {'Male':[32,33,34,
                 'Small (37,38)','Medium (39,40)',
                 'Large (41, 42)', 'XL (43,44)',
                 '2XL (45, 46)', '3XL (47,48)',
                 '4XL (49, 50)'
                ],
         'Female': [36,38,40,42,44,46,48,50]
        
        }

# female_plain = [32,33,34]

turkish_female_size = ['6','Small (8)','Medium (10)'
                        'Large (12)', 'XL (14)',
                       '2XL (16)', '3XL (18)',
                         '4XL (20)'
                      
                      ]

sex = ['Male','Female']

sleeves = ['long','Short']

first_turkish_shirt_brand = ['Tim',"Segrato","Balenciaga","Valente",
                       'casual']
brands_ = ['None']

product = 'Shirt'
types = {'Normal (casual) Shirt':['Plain','Designer Collar','Front Design',
                                  'Check','Stripe','Designer'],
            '1st Turkish Shirt':['Plain','Color Neck','Stripe','WYN Neck',
                                 'Check','Dotted',"Flower",
                               ],
            '2nd Turkish Shirt':['Plain','Big Body with Small Neck',
                                 'Bishop Neck','Check'],
           }

# %%
data = []
for gender in sex:
    temp = []
    for cat, types_ in types.items():
        if cat == '1st Turkish Shirt':
            brands = first_turkish_shirt_brand
        else:
            brands = brands_
            
        if 'Turkish' in cat and gender == "Female":
            print('seen')
            sizes = turkish_female_size
        else:
            sizes = sizes_
        
        for type_ in types_:
            for brand in brands:
                
                for sleeve in sleeves:

                    for brand in brands:

                        for color in colors:
                            try:
                                for size in sizes[gender]:
                                    temp = [product,cat,brand,type_,gender,
                                            color,size,sleeve]
                                    data.append(temp)
                            except TypeError :
                                for size in sizes:
                                    temp = [product,cat,brand,type_,gender,
                                            color,size,sleeve]
                                    data.append(temp)


len(temp)
# Out:
# seen
# seen
# 8

# %%
shirts = pd.DataFrame(data,columns=cols)

# %%
shirts[(shirts.Category == '1st Turkish Shirt') & (shirts.sex == 'Female')  ]
# Out:
#        Product           Category   Brand    Type     sex  Color  \
# 72124    Shirt  1st Turkish Shirt     Tim   Plain  Female  white
# 72125    Shirt  1st Turkish Shirt     Tim   Plain  Female  white
# 72126    Shirt  1st Turkish Shirt     Tim   Plain  Female  white
# 72127    Shirt  1st Turkish Shirt     Tim   Plain  Female  white
# 72128    Shirt  1st Turkish Shirt     Tim   Plain  Female  white
# ...        ...                ...     ...     ...     ...    ...
# 118669   Shirt  1st Turkish Shirt  casual  Flower  Female  Peach
# 118670   Shirt  1st Turkish Shirt  casual  Flower  Female  Peach
# 118671   Shirt  1st Turkish Shirt  casual  Flower  Female  Peach
# 118672   Shirt  1st Turkish Shirt  casual  Flower  Female  Peach
# 118673   Shirt  1st Turkish Shirt  casual  Flower  Female  Peach
#
#                          Size sleeves
# 72124                       6    long
# 72125               Small (8)    long
# 72126   Medium (10)Large (12)    long
# ...

# %%
cols = ['Product','Category','Brand','Type',
        'sex','Color','Size','sleeves',
       ]
colors = []
# colors_and_check = ['Black','Dark Blue','Navy Blue','Royal Blue'
#           'Light Blue','Sky Blue','Ash','Dark Ash',
#           'Grey','Dark Grey','Coffee Brown','Carton',
#           'Green','Wine / Maroon','Red', 
#           'Navy Blue and Yellow', 'Ash and Yellow',
#           'Dark Ash and Yellow','Light Blue and Yellow'
#          ]
colors = ['white','Black','Sky Blue',
               'Navy Blue','Light Blue','Ash', 'Dark Blue',
               'Grey', 'Dark Grey','Brown','Green','Light Green',
               'Wine / Maroon','Purple','Pink',
               'Red','Lemon','Peach'
               
         ]

sizes = [36,38,40,42,44,46,48,50,52,54,56,58,60,62,64,66]

sex = ['Unisex']

sleeves = ['None']

brands = ['None']

product = 'Jacket'
types = {'Inner Jacket / Waist Coat':['Turkish','Normal','stock',
                            ],
         'Travelling Suit Jacket':['Turkish','Normal','stock',
                            ],
         'Jeans Jacket':['Turkish','Normal','stock',
                            ],
         'Winter Jacket':['Turkish','Normal','stock',
                            ],
         'Cold Jacket':['Turkish','Normal','stock',
                            ],
            'Monkey Jacket':['Plain','Stripe','Check','Dotted',
                             "Rough Surface",
                               ],
           }

# %%
data = []
for gender in sex:
    temp = []
    for cat, types_ in types.items():
        if cat == 'Cold Jacket':
            sleeves = ["Long"]
        else:
            sleeves = ["None"]
            
        for type_ in types_:
            for brand in brands:
                
                for sleeve in sleeves:

                    for brand in brands:

                        for color in colors:
                            try:
                                for size in sizes[gender]:
                                    temp = [product,cat,brand,type_,gender,
                                            color,size,sleeve]
                                    data.append(temp)
                            except TypeError :
                                for size in sizes:
                                    temp = [product,cat,brand,type_,gender,
                                            color,size,sleeve]
                                    data.append(temp)


len(temp)
# Out:
# 8

# %%
jackets= pd.DataFrame(data,columns=cols)

# %%
jackets
# Out:
#      Product                   Category Brand           Type     sex  Color  \
# 0     Jacket  Inner Jacket / Waist Coat  None        Turkish  Unisex  white
# 1     Jacket  Inner Jacket / Waist Coat  None        Turkish  Unisex  white
# 2     Jacket  Inner Jacket / Waist Coat  None        Turkish  Unisex  white
# 3     Jacket  Inner Jacket / Waist Coat  None        Turkish  Unisex  white
# 4     Jacket  Inner Jacket / Waist Coat  None        Turkish  Unisex  white
# ...      ...                        ...   ...            ...     ...    ...
# 5755  Jacket              Monkey Jacket  None  Rough Surface  Unisex  Peach
# 5756  Jacket              Monkey Jacket  None  Rough Surface  Unisex  Peach
# 5757  Jacket              Monkey Jacket  None  Rough Surface  Unisex  Peach
# 5758  Jacket              Monkey Jacket  None  Rough Surface  Unisex  Peach
# 5759  Jacket              Monkey Jacket  None  Rough Surface  Unisex  Peach
#
#       Size sleeves
# 0       36    None
# ...

# %%
jackets[jackets.sleeves == "Long"]
# Out:
#      Product     Category Brand     Type     sex  Color  Size sleeves
# 3456  Jacket  Cold Jacket  None  Turkish  Unisex  white    36    Long
# 3457  Jacket  Cold Jacket  None  Turkish  Unisex  white    38    Long
# 3458  Jacket  Cold Jacket  None  Turkish  Unisex  white    40    Long
# 3459  Jacket  Cold Jacket  None  Turkish  Unisex  white    42    Long
# 3460  Jacket  Cold Jacket  None  Turkish  Unisex  white    44    Long
# ...      ...          ...   ...      ...     ...    ...   ...     ...
# 4315  Jacket  Cold Jacket  None    stock  Unisex  Peach    58    Long
# 4316  Jacket  Cold Jacket  None    stock  Unisex  Peach    60    Long
# 4317  Jacket  Cold Jacket  None    stock  Unisex  Peach    62    Long
# 4318  Jacket  Cold Jacket  None    stock  Unisex  Peach    64    Long
# 4319  Jacket  Cold Jacket  None    stock  Unisex  Peach    66    Long
#
# [864 rows x 8 columns]

# %%
cols = ['Product','Category','Brand','Type',
        'sex','Color','Size'
       ]
colors = []
# colors_and_check = ['Black','Dark Blue','Navy Blue','Royal Blue'
#           'Light Blue','Sky Blue','Ash','Dark Ash',
#           'Grey','Dark Grey','Coffee Brown','Carton',
#           'Green','Wine / Maroon','Red', 
#           'Navy Blue and Yellow', 'Ash and Yellow',
#           'Dark Ash and Yellow','Light Blue and Yellow'
#          ]
colors = ['white','Black',
            'Navy Blue','Ash',
            'Grey', 'Dark Grey','Brown','Green',
               'Wine / Maroon','Purple','Pink',
               'Yellow','Carton','Stone','Milk',
              'Designer','Offmilk'
               
         ]

sizes = [36,38,40,42,44,46,48,50,52,54,56,58,60,62,64,66]

sex = ['Male',"Female"]

brands = ['None']

product = 'Trousers'
types = ['Stock','Normal']

Category = ['Chinose','Plain','Jeans','Dotted',
            'Turkish','Joggers','Pant','Valvet',
            'Knicker','Codro'
           ]

# %%
data = []
for gender in sex:
    temp = []
    for cat in Category:
        if cat == 'Jeans':
            types_ = [*types,'Combat']
        else:
            types_ = types
            
        for type_ in types_:
            for brand in brands:
                for color in colors:
                    try:
                        for size in sizes[gender]:
                            temp = [product,cat,brand,type_,gender,
                                        color,size,sleeve]
                            data.append(temp)
                    except TypeError :
                        for size in sizes:
                            temp = [product,cat,brand,type_,gender,
                                    color,size]
                            data.append(temp)


trousers= pd.DataFrame(data,columns=cols)

# %%
trousers
# Out:
#         Product Category Brand    Type     sex    Color  Size
# 0      Trousers  Chinose  None   Stock    Male    white    36
# 1      Trousers  Chinose  None   Stock    Male    white    38
# 2      Trousers  Chinose  None   Stock    Male    white    40
# 3      Trousers  Chinose  None   Stock    Male    white    42
# 4      Trousers  Chinose  None   Stock    Male    white    44
# ...         ...      ...   ...     ...     ...      ...   ...
# 11419  Trousers    Codro  None  Normal  Female  Offmilk    58
# 11420  Trousers    Codro  None  Normal  Female  Offmilk    60
# 11421  Trousers    Codro  None  Normal  Female  Offmilk    62
# 11422  Trousers    Codro  None  Normal  Female  Offmilk    64
# 11423  Trousers    Codro  None  Normal  Female  Offmilk    66
#
# [11424 rows x 7 columns]

# %%
cols = ['Product','Category','Brand','Type',
        'sex','Color','Size'
       ]
colors = []
# colors_and_check = ['Black','Dark Blue','Navy Blue','Royal Blue'
#           'Light Blue','Sky Blue','Ash','Dark Ash',
#           'Grey','Dark Grey','Coffee Brown','Carton',
#           'Green','Wine / Maroon','Red', 
#           'Navy Blue and Yellow', 'Ash and Yellow',
#           'Dark Ash and Yellow','Light Blue and Yellow'
#          ]
colors = ['white','Black',
            'Navy Blue','Ash',
            'Grey', 'Dark Grey','Brown','Green',
               'Wine / Maroon','Purple','Pink',
               'Yellow','Carton','Stone','Milk',
              'Designer','Offmilk'
               
         ]

sizes = [36,38,40,42,44,46,48,50,52,54,56,58,60,62,64,66]

sex = ['Male',"Female"]

brands = ['None']

product = 'Shorts'
types = ['Stock','Normal']

Category = ['Chinose','Plain','Jeans',
            'Liv','Valvet','Knicker','3/4'
           ]

# %%
data = []
for gender in sex:
    temp = []
    for cat in Category:
        if cat == 'Jeans':
            types_ = [*types,'Combat']
        else:
            types_ = types
            
        for type_ in types_:
            for brand in brands:
                for color in colors:
                    try:
                        for size in sizes[gender]:
                            temp = [product,cat,brand,type_,gender,
                                        color,size,sleeve]
                            data.append(temp)
                    except TypeError :
                        for size in sizes:
                            temp = [product,cat,brand,type_,gender,
                                    color,size]
                            data.append(temp)


shorts= pd.DataFrame(data,columns=cols)

# %%
shorts
# Out:
#      Product Category Brand    Type     sex    Color  Size
# 0     Shorts  Chinose  None   Stock    Male    white    36
# 1     Shorts  Chinose  None   Stock    Male    white    38
# 2     Shorts  Chinose  None   Stock    Male    white    40
# 3     Shorts  Chinose  None   Stock    Male    white    42
# 4     Shorts  Chinose  None   Stock    Male    white    44
# ...      ...      ...   ...     ...     ...      ...   ...
# 8155  Shorts      3/4  None  Normal  Female  Offmilk    58
# 8156  Shorts      3/4  None  Normal  Female  Offmilk    60
# 8157  Shorts      3/4  None  Normal  Female  Offmilk    62
# 8158  Shorts      3/4  None  Normal  Female  Offmilk    64
# 8159  Shorts      3/4  None  Normal  Female  Offmilk    66
#
# [8160 rows x 7 columns]

# %%
cols = ['Product','Category','Brand','Type',
        'sex','Color','Size','sleeve',
       ]
colors = []

colors = ['white','Black',
            'Navy Blue','Ash',
            'Grey', 'Dark Grey','Brown','Green',
               'Wine / Maroon','Purple','Pink',
               'Yellow','Carton','Stone','Milk',
              'Designer','Offmilk'
               
         ]

sizes = [36,38,40,42,44,46,48,50,52,54,56,58,60,62,64,66]

sex = ['Unisex']

brands = ['None']
sleeves = ['long','Short']
product = 'Polo'
types = ['Stock','Normal']

Category = ['Round Neck','V Neck',
           ]

# %%
data = []
for gender in sex:
    temp = []
    for  cat in Category:
        for type_ in types:
            for sleeve in sleeves:

                for brand in brands:

                    for color in colors:
                        try:
                            for size in sizes[gender]:
                                temp = [product,cat,brand,type_,gender,
                                        color,size,sleeve]
                                data.append(temp)
                        except TypeError :
                            for size in sizes:
                                temp = [product,cat,brand,type_,gender,
                                        color,size,sleeve]
                                data.append(temp)

polo = pd.DataFrame(data,columns=cols)

# %%
polo
# Out:
#      Product    Category Brand    Type     sex    Color  Size sleeve
# 0       Polo  Round Neck  None   Stock  Unisex    white    36   long
# 1       Polo  Round Neck  None   Stock  Unisex    white    38   long
# 2       Polo  Round Neck  None   Stock  Unisex    white    40   long
# 3       Polo  Round Neck  None   Stock  Unisex    white    42   long
# 4       Polo  Round Neck  None   Stock  Unisex    white    44   long
# ...      ...         ...   ...     ...     ...      ...   ...    ...
# 2171    Polo      V Neck  None  Normal  Unisex  Offmilk    58  Short
# 2172    Polo      V Neck  None  Normal  Unisex  Offmilk    60  Short
# 2173    Polo      V Neck  None  Normal  Unisex  Offmilk    62  Short
# 2174    Polo      V Neck  None  Normal  Unisex  Offmilk    64  Short
# 2175    Polo      V Neck  None  Normal  Unisex  Offmilk    66  Short
#
# [2176 rows x 8 columns]

# %%
cols = ['Product','Category','Brand','Type',
        'sex','Color','Size','sleeve',
       ]
colors = []

colors = ['white','Black',
            'Navy Blue','Ash',
            'Grey', 'Dark Grey','Brown','Green',
               'Wine / Maroon','Purple','Pink',
               'Yellow','Carton','Stone','Milk',
              'Designer','Offmilk'
               
         ]

sizes = [36,38,40,42,44,46,48,50,52,54,56,58,60,62,64,66]

sex = ['Unisex']

brands = ['None']
sleeves = ['long','Short']
product = 'Turtle Neck'
types = ['Stock','Normal']

Category = ['Plain','Stripe','Check',
         # 'Codro'
        ]

data = []
for gender in sex:
    temp = []
    for  cat in Category:
        for type_ in types:
            for sleeve in sleeves:

                for brand in brands:

                    for color in colors:
                        try:
                            for size in sizes[gender]:
                                temp = [product,cat,brand,type_,gender,
                                        color,size,sleeve]
                                data.append(temp)
                        except TypeError :
                            for size in sizes:
                                temp = [product,cat,brand,type_,gender,
                                        color,size,sleeve]
                                data.append(temp)

turtle_neck = pd.DataFrame(data,columns=cols)
turtle_neck
# Out:
#           Product Category Brand    Type     sex    Color  Size sleeve
# 0     Turtle Neck    Plain  None   Stock  Unisex    white    36   long
# 1     Turtle Neck    Plain  None   Stock  Unisex    white    38   long
# 2     Turtle Neck    Plain  None   Stock  Unisex    white    40   long
# 3     Turtle Neck    Plain  None   Stock  Unisex    white    42   long
# 4     Turtle Neck    Plain  None   Stock  Unisex    white    44   long
# ...           ...      ...   ...     ...     ...      ...   ...    ...
# 3259  Turtle Neck    Check  None  Normal  Unisex  Offmilk    58  Short
# 3260  Turtle Neck    Check  None  Normal  Unisex  Offmilk    60  Short
# 3261  Turtle Neck    Check  None  Normal  Unisex  Offmilk    62  Short
# 3262  Turtle Neck    Check  None  Normal  Unisex  Offmilk    64  Short
# 3263  Turtle Neck    Check  None  Normal  Unisex  Offmilk    66  Short
#
# [3264 rows x 8 columns]

# %%
cols = ['Product','Category','Brand','Type',
        'sex','Color','Size','sleeve',
       ]

colors = ['white','Black',
            'Navy Blue','Ash',
         ]

sizes = [36,38,40,42,44,46,48,50,52,54,56,58,60,62,64,66]

sex = ['Unisex']

brands = ['None']
sleeves = ['None']
product = 'Boxers'
types = ['Normal','Stock']

Category = ['3 in 1','2 in 1',
            'Single',
            'Banana'
         # 'Codro'
        ]

data = []
for gender in sex:
    temp = []
    for  cat in Category:
        for type_ in types:
            for sleeve in sleeves:

                for brand in brands:

                    for color in colors:
                        try:
                            for size in sizes[gender]:
                                temp = [product,cat,brand,type_,gender,
                                        color,size,sleeve]
                                data.append(temp)
                        except TypeError :
                            for size in sizes:
                                temp = [product,cat,brand,type_,gender,
                                        color,size,sleeve]
                                data.append(temp)

boxers = pd.DataFrame(data,columns=cols)
boxers
# Out:
#     Product Category Brand    Type     sex  Color  Size sleeve
# 0    Boxers   3 in 1  None  Normal  Unisex  white    36   None
# 1    Boxers   3 in 1  None  Normal  Unisex  white    38   None
# 2    Boxers   3 in 1  None  Normal  Unisex  white    40   None
# 3    Boxers   3 in 1  None  Normal  Unisex  white    42   None
# 4    Boxers   3 in 1  None  Normal  Unisex  white    44   None
# ..      ...      ...   ...     ...     ...    ...   ...    ...
# 507  Boxers   Banana  None   Stock  Unisex    Ash    58   None
# 508  Boxers   Banana  None   Stock  Unisex    Ash    60   None
# 509  Boxers   Banana  None   Stock  Unisex    Ash    62   None
# 510  Boxers   Banana  None   Stock  Unisex    Ash    64   None
# 511  Boxers   Banana  None   Stock  Unisex    Ash    66   None
#
# [512 rows x 8 columns]

# %%
cols = ['Product','Category','Brand','Type',
        'sex','Color','Size','sleeve',
       ]

colors = ['white']

sizes = [36,38,40,42,44,46,48,50,52,54,56,58,60,62,64,66]

sex = ['Unisex']

brands = ['Lux','Versace','Gucci',
          'Cartelo','Tommy','Fendi',
          'Emperior Armani','Lascote',
          'Boss','Calvin Klein','Hermes',
          'DG','Burberry','Addidas',
          'T&H','Moncler','Dior','L.V',
          
         
         ]
sleeves = ['None']
product = 'Pant'
types = ['Cotton','Higher Cotton','Condom']

Category = ['3 in 1','2 in 1',
            'Single',
         # 'Codro'
        ]

data = []
for gender in sex:
    temp = []
    for  cat in Category:
        for type_ in types:
            for sleeve in sleeves:

                for brand in brands:

                    for color in colors:
                        try:
                            for size in sizes[gender]:
                                temp = [product,cat,brand,type_,gender,
                                        color,size,sleeve]
                                data.append(temp)
                        except TypeError :
                            for size in sizes:
                                temp = [product,cat,brand,type_,gender,
                                        color,size,sleeve]
                                data.append(temp)

pants = pd.DataFrame(data,columns=cols)
pants
# Out:
#      Product Category Brand    Type     sex  Color  Size sleeve
# 0       Pant   3 in 1   Lux  Cotton  Unisex  white    36   None
# 1       Pant   3 in 1   Lux  Cotton  Unisex  white    38   None
# 2       Pant   3 in 1   Lux  Cotton  Unisex  white    40   None
# 3       Pant   3 in 1   Lux  Cotton  Unisex  white    42   None
# 4       Pant   3 in 1   Lux  Cotton  Unisex  white    44   None
# ...      ...      ...   ...     ...     ...    ...   ...    ...
# 2587    Pant   Single   L.V  Condom  Unisex  white    58   None
# 2588    Pant   Single   L.V  Condom  Unisex  white    60   None
# 2589    Pant   Single   L.V  Condom  Unisex  white    62   None
# 2590    Pant   Single   L.V  Condom  Unisex  white    64   None
# 2591    Pant   Single   L.V  Condom  Unisex  white    66   None
#
# [2592 rows x 8 columns]

# %%
cols = ['Product','Category','Brand','Type',
        'sex','Color','Size','sleeve',
       ]

colors = ['white','Black',
            'Navy Blue','Ash',
         ]

sizes = [36,38,40,42,44,46,48,50,52,54,56,58,60,62,64,66]

sex = ['Unisex']

brands = ['None']
sleeves = ['None']
product = 'Singlet'
types = ['Normal','Stock']

Category = ['3 in 1','Single',
            '2 in 1'
         # 'Codro'
        ]

data = []
for gender in sex:
    temp = []
    for  cat in Category:
        for type_ in types:
            for sleeve in sleeves:

                for brand in brands:

                    for color in colors:
                        try:
                            for size in sizes[gender]:
                                temp = [product,cat,brand,type_,gender,
                                        color,size,sleeve]
                                data.append(temp)
                        except TypeError :
                            for size in sizes:
                                temp = [product,cat,brand,type_,gender,
                                        color,size,sleeve]
                                data.append(temp)

Singlet = pd.DataFrame(data,columns=cols)
Singlet
# Out:
#      Product Category Brand    Type     sex  Color  Size sleeve
# 0    Singlet   3 in 1  None  Normal  Unisex  white    36   None
# 1    Singlet   3 in 1  None  Normal  Unisex  white    38   None
# 2    Singlet   3 in 1  None  Normal  Unisex  white    40   None
# 3    Singlet   3 in 1  None  Normal  Unisex  white    42   None
# 4    Singlet   3 in 1  None  Normal  Unisex  white    44   None
# ..       ...      ...   ...     ...     ...    ...   ...    ...
# 379  Singlet   2 in 1  None   Stock  Unisex    Ash    58   None
# 380  Singlet   2 in 1  None   Stock  Unisex    Ash    60   None
# 381  Singlet   2 in 1  None   Stock  Unisex    Ash    62   None
# 382  Singlet   2 in 1  None   Stock  Unisex    Ash    64   None
# 383  Singlet   2 in 1  None   Stock  Unisex    Ash    66   None
#
# [384 rows x 8 columns]

# %%
cols = ['Product','Category','Brand','Type',
        'sex','Color','Size','sleeve',
       ]

colors = {'Manchester United':['Red','Black','White & Black','Grey and White'],
          'Chelsea':['Blue','Yellow'],
         'Liverpool':['Red'],
          'Arsenal':['Red','Yellow','Green'],
         'Manchester City':['Blue','Dark Blue','Light Blue'],
          'Bacar':['Blue','Red and Blue'],
         'Real Madrid':['White'],
          'PSG':['Dark Blue','White and Blue'],
         'Bayern Munich':['Black'],
         'NFF':['Green','Green and White','Green Armless']
         
         
         }

sizes = [36,38,40,42,44,46,48,50,52,54,56,58,60,62,64,66]

sex = ['Unisex']

types = ['Collar','Non Collar']
sleeves = ['short']
product = 'Jersey'
brands = ['Manchester United','Chelsea',
        'Liverpool','Arsenal',
         'Manchester City', 'Bacar',
        'Real Madrid','PSG',
         'Bayern Munich',
         'NFF'
        ]

Category = ['Normal','Original / Player version',
            'Children (Up and Down)'
         # 'Codro'
        ]

data = []
for gender in sex:
    temp = []
    for  cat in Category:
        for type_ in types:
            for sleeve in sleeves:

                for brand in brands:

                    for color in colors[brand]:
                        try:
                            for size in sizes[gender]:
                                temp = [product,cat,brand,type_,gender,
                                        color,size,sleeve]
                                data.append(temp)
                        except TypeError :
                            for size in sizes:
                                temp = [product,cat,brand,type_,gender,
                                        color,size,sleeve]
                                data.append(temp)

Jersey = pd.DataFrame(data,columns=cols)
Jersey
# Out:
#      Product                Category              Brand        Type     sex  \
# 0     Jersey                  Normal  Manchester United      Collar  Unisex
# 1     Jersey                  Normal  Manchester United      Collar  Unisex
# 2     Jersey                  Normal  Manchester United      Collar  Unisex
# 3     Jersey                  Normal  Manchester United      Collar  Unisex
# 4     Jersey                  Normal  Manchester United      Collar  Unisex
# ...      ...                     ...                ...         ...     ...
# 2107  Jersey  Children (Up and Down)                NFF  Non Collar  Unisex
# 2108  Jersey  Children (Up and Down)                NFF  Non Collar  Unisex
# 2109  Jersey  Children (Up and Down)                NFF  Non Collar  Unisex
# 2110  Jersey  Children (Up and Down)                NFF  Non Collar  Unisex
# 2111  Jersey  Children (Up and Down)                NFF  Non Collar  Unisex
#
#               Color  Size sleeve
# ...
