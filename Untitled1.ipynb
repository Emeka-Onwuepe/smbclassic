# %%
import pandas as pd
import numpy as np

# %%
cols = ['Product','Category','Brand','Type',
        'Color','Size',
       ]

colors = ['Light Brown','C/Brown','Black',
          ]

sizes = ['None']

sex = ['Unisex']

brands = ['None']
product = 'Belt'
types = ['Normal Head (Big)','Normal Head (Slim)',
        'Cover Head (Big)','Cover Head (Slim)'
        ]

Category = ['Normal','Original','Ordinary']

data = []


for  cat in Category:
    temp = []
    for type_ in types:
        
        for brand in brands:

            for color in colors:
                for size in sizes:
                    temp = [product,cat,brand,type_,
                            color,size,]
                    data.append(temp)
                       

Belt = pd.DataFrame(data,columns=cols)
Belt
# Out:
#    Product  Category Brand                Type        Color  Size
# 0     Belt    Normal  None   Normal Head (Big)  Light Brown  None
# 1     Belt    Normal  None   Normal Head (Big)      C/Brown  None
# 2     Belt    Normal  None   Normal Head (Big)        Black  None
# 3     Belt    Normal  None  Normal Head (Slim)  Light Brown  None
# 4     Belt    Normal  None  Normal Head (Slim)      C/Brown  None
# 5     Belt    Normal  None  Normal Head (Slim)        Black  None
# 6     Belt    Normal  None    Cover Head (Big)  Light Brown  None
# 7     Belt    Normal  None    Cover Head (Big)      C/Brown  None
# 8     Belt    Normal  None    Cover Head (Big)        Black  None
# 9     Belt    Normal  None   Cover Head (Slim)  Light Brown  None
# 10    Belt    Normal  None   Cover Head (Slim)      C/Brown  None
# 11    Belt    Normal  None   Cover Head (Slim)        Black  None
# 12    Belt  Original  None   Normal Head (Big)  Light Brown  None
# ...

# %%
cols = ['Product','Category','Brand','Type','Color','Size',
       ]
data = [
    ['Hand Bracelet','None','None','None','None','None'],
    ['Pocket Wallet','None','None','None','None','Long'],
    ['Pocket Wallet','None','None','None','None','Short'],
    ['Hand Wallet','None','None','None','None','Small'],
    ['Hand Wallet','None','None','None','None','Medium'],
    ['Hand Wallet','None','None','None','None','Big'],
    ['Tie Clip','Normal','None','None','None','None'],  
    ['Tie Clip','With Box','None','None','None','None'],
    
    ['Cufflinks','None','None','Normal','None','None'],  
    ['Cufflinks','None','None','Stock','None','None'],
    ['Cufflinks','Cufflinks with Buttons','None','Stock','None','None'], 
    
    
    ['Tie','Single Tie','None','Normal','None','None'],  
    ['Tie','Single Tie','None','Turkish','None','None'],
    ['Tie','Bow-Tie','None','Normal','None','None'],  
    ['Tie','Bow-Tie','None','Stock','None','None'],
    ['Tie','Bold-Tie','None','Stock','None','None'],
    ['Tie',' Buterfly Bow-Tie','None','Normal','None','None'],  
    ['Tie','Buterfly Bow-Tie','None','Stock','None','None'],
        
    ['Tie','Bow-Tie with Cufflinks','None','Stock','None','None'],
    ['Tie','Bow-Tie with Cufflinks and Waist Band','None','Stock','None','None'],
    ['Tie','Packet/Box Tie with Cufflinks','None','Stock','None','None'],
    ['Tie','Buterfly Bow Tie with Cufflinks','None','Stock','None','None'],
    ['Tie','Buterfly Bow Tie with Chest Flower','None','Stock','None','None'],
    
    ['Brooch','None','None','None','None','None'],  
    ['Chest Flower','None','None','None','None','None'],
    ['Lapel Chain','None','None','None','None','None'],  
    ['Chest Logo','None','None','None','None','None'], 
    ['Head Warmer','None','None','None','None','None'],
    ['Hat','None','None','None','None','None'],
    ['Suspender/Cross Belt','None','None','None','None','None'],
    ['Suit Cleaner','None','None','None','None','None'],
    ['Handkerchief','None','None','Normal','None','None'],
    ['Handkerchief','None','None','Original','None','None'],
    
    ['Cap','Face Cap','None','None','None','None'],
    ['Cap','Pea Cap','None','None','None','None'],
    ['Cap','Papas Cap','None','None','None','None'],
  
]

many = pd.DataFrame(data,columns=cols)
many
# Out:
#                  Product                               Category Brand  \
# 0          Hand Bracelet                                   None  None
# 1          Pocket Wallet                                   None  None
# 2          Pocket Wallet                                   None  None
# 3            Hand Wallet                                   None  None
# 4            Hand Wallet                                   None  None
# 5            Hand Wallet                                   None  None
# 6               Tie Clip                                 Normal  None
# 7               Tie Clip                               With Box  None
# 8              Cufflinks                                   None  None
# 9              Cufflinks                                   None  None
# 10             Cufflinks                 Cufflinks with Buttons  None
# 11                   Tie                             Single Tie  None
# ...
